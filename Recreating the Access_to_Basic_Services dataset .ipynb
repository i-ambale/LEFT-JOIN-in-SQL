# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Recreating the Access_to_Basic_Services dataset
# © ExploreAI Academy

# %% [markdown]
# In this notebook, we cover how ERDs help us understand database joins better. We also focus on the `LEFT JOIN` technique and highlight the importance of picking the right joining strategy, as incorrect joins can lead to inaccurate results.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you will:
# - Understand how Entity-Relationship Diagrams can help us understand database joins better.
# - Understand the `LEFT JOIN` technique and how it is used to combine tables.
# - Know the importance of picking the right joining strategy and how incorrect joins can lead to inaccurate results.

# %% [markdown]
# ## Overview
#
# Entity-Relationship diagrams play a valuable role in determining the table relationships and join strategies within a database. They provide the means to make informed decisions about which tables to join and the appropriate method for doing so.
#
#
# Let’s recall our united_nations ERD which has three entities: Geographic_Location, Basic_Services, and Economic_Indicators.
#
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Northwind_ERD.png" alt= "united_nations ERD" width="60%" height="60%">

# %% [markdown]
# One common joining technique involves selecting a central table that serves as the core of all relationships in the database and employing a `LEFT JOIN`.
# In our case, the `Geographic_Location` table would be the central table.
#
# With a `LEFT JOIN`, all records from the left table are returned, along with the corresponding matching records from the right table. In cases where there is no match, the result will include NULL values on the right side.

# %% [markdown]
# ## Connecting to our MySQL database
#
# We'll start by connecting to the `united_nations` database. To connect to the MySQL server, run the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql
# Out:
# c:\Users\PC\anaconda3\envs\DS_Python\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:20!_Ke&Y@localhost:3306/united_nations

# %% [markdown]
# We'll then use a simple `SELECT` query to fetch all records from the `Geographic_Location` table.

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. First `LEFT JOIN`
#
# Combine the `Geographic_Location` table with the `Economic_Indicators` table based on the `Country_name` column.

# %%
# %%sql
# # Add your code here
# # Use LIMIT if you expect a large result set
#
# SELECT
#     *
# FROM
#     Geographic_Location
# LEFT JOIN
#     Economic_Indicators ON Geographic_Location.Country_name = Economic_Indicators.Country_name
# LIMIT 100;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 100 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.0000'), 34, None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.0200'), 35, None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.9000'), 36, Decimal('11.18')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.4200'), 37, None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2019, Decimal('18.9000'), 38, None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2020, Decimal('20.1400'), 39, Decimal('11.71')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2015, Decimal('165.9800'), 40, Decimal('11.21')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2016, Decimal('160.0300'), 40, Decimal('10.20')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2017, Decimal('170.1000'), 41, Decimal('12.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2018, Decimal('174.9100'), 42, None),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2019, Decimal('171.7700'), 43, None),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2020, Decimal('145.0100'), 43, None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2015, Decimal('0.6700'), 0, None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2016, Decimal('0.6700'), 0, None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2017, Decimal('0.6100'), 0, None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2018, Decimal('0.6400'), 0, None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2019, Decimal('0.6500'), 0, None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2020, Decimal('0.7200'), 0, None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2015, Decimal('87.2200'), 28, None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2016, Decimal('49.8400'), 29, None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2017, Decimal('68.9700'), 30, None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2018, Decimal('77.7900'), 31, None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2019, Decimal('69.3100'), 32, Decimal('16.50')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2020, Decimal('53.6200'), 33, None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2015, None, None, None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2016, None, None, None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2017, None, None, None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2015, Decimal('1.3400'), 0, None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2016, Decimal('1.4400'), 0, None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2017, Decimal('1.4700'), 0, None),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2015, Decimal('594.7500'), 43, None),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2016, Decimal('557.5300'), 44, None),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2017, Decimal('643.6300'), 44, Decimal('8.35')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2018, Decimal('524.8200'), 44, Decimal('9.22')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2019, Decimal('447.7500'), 45, Decimal('9.84')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2020, Decimal('385.5400'), 45, Decimal('11.46')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2015, Decimal('10.5500'), 3, Decimal('18.26')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2016, Decimal('10.5500'), 3, Decimal('17.62')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2017, Decimal('11.5300'), 3, Decimal('17.70')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2018, Decimal('12.4600'), 3, Decimal('13.21')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2019, Decimal('13.6200'), 3, Decimal('12.20')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2020, Decimal('12.6400'), 3, Decimal('12.18')),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.00'), 'Aruba', 2015, Decimal('2.9600'), 0, None),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.00'), 'Aruba', 2016, Decimal('2.9800'), 0, None),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2015, Decimal('1350.6200'), 24, Decimal('6.06')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2016, Decimal('1206.5400'), 24, Decimal('5.71')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2017, Decimal('1326.5200'), 25, Decimal('5.59')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2018, Decimal('1428.2900'), 25, Decimal('5.30')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2019, Decimal('1392.2300'), 25, Decimal('5.16')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2020, Decimal('1326.9000'), 26, Decimal('6.46')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.17'), 'Azerbaijan', 2015, Decimal('53.0700'), 10, Decimal('4.96')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.17'), 'Azerbaijan', 2016, Decimal('37.8700'), 10, Decimal('5.00')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.17'), 'Azerbaijan', 2017, Decimal('40.8700'), 10, Decimal('4.96')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.17'), 'Azerbaijan', 2018, Decimal('47.1100'), 10, Decimal('4.94')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.17'), 'Azerbaijan', 2019, Decimal('48.1700'), 10, Decimal('4.85')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.17'), 'Azerbaijan', 2020, Decimal('42.6900'), 10, Decimal('7.16')),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None, 'Bahamas', 2015, None, None, None),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None, 'Bahamas', 2016, None, None, None),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None, 'Bahamas', 2017, None, None, None),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None, 'Bahamas', 2018, None, None, None),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None, 'Bahamas', 2019, None, None, None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.83'), 'Bahrain', 2015, Decimal('31.0500'), 1, None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.83'), 'Bahrain', 2016, Decimal('32.2300'), 1, None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.83'), 'Bahrain', 2017, Decimal('35.4700'), 1, None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.83'), 'Bahrain', 2018, Decimal('37.8000'), 1, None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.83'), 'Bahrain', 2019, Decimal('38.6500'), 1, None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.83'), 'Bahrain', 2020, Decimal('34.7200'), 1, None),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00'), 'Bangladesh', 2015, Decimal('195.0800'), 158, None),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00'), 'Bangladesh', 2016, Decimal('265.2400'), 160, Decimal('4.35')),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00'), 'Bangladesh', 2017, Decimal('293.7500'), 162, Decimal('4.37')),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00'), 'Bangladesh', 2018, Decimal('321.3800'), 164, None),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00'), 'Bangladesh', 2019, Decimal('351.2400'), 166, None),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.00'), 'Bangladesh', 2020, Decimal('373.9000'), 167, None),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00'), 'Barbados', 2015, Decimal('4.7200'), 0, Decimal('9.80')),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00'), 'Barbados', 2016, Decimal('4.8300'), 0, Decimal('8.25')),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00'), 'Barbados', 2017, Decimal('4.9800'), 0, Decimal('8.62')),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00'), 'Barbados', 2018, Decimal('5.1000'), 0, Decimal('8.32')),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00'), 'Barbados', 2019, Decimal('5.3200'), 0, Decimal('8.41')),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.00'), 'Barbados', 2020, Decimal('4.6700'), 0, None),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00'), 'Belize', 2015, Decimal('2.2100'), 0, Decimal('7.58')),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00'), 'Belize', 2016, Decimal('2.2600'), 0, Decimal('7.00')),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00'), 'Belize', 2017, Decimal('2.2900'), 0, Decimal('6.60')),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00'), 'Belize', 2018, Decimal('2.3100'), 0, None),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00'), 'Belize', 2019, Decimal('2.4200'), 0, Decimal('9.05')),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.00'), 'Belize', 2020, Decimal('2.0800'), 0, None),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00'), 'Benin', 2015, Decimal('11.3900'), 11, None),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00'), 'Benin', 2016, Decimal('11.8200'), 11, None),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00'), 'Benin', 2017, Decimal('12.7000'), 12, None),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00'), 'Benin', 2018, Decimal('14.2600'), 12, Decimal('1.47')),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00'), 'Benin', 2019, Decimal('14.3900'), 12, None),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.00'), 'Benin', 2020, Decimal('15.6500'), 13, None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00'), 'Bermuda', 2015, Decimal('6.6500'), 0, None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00'), 'Bermuda', 2016, Decimal('6.9000'), 0, None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00'), 'Bermuda', 2017, Decimal('7.1400'), 0, None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00'), 'Bermuda', 2018, Decimal('7.2300'), 0, None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00'), 'Bermuda', 2019, Decimal('7.4200'), 0, None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.00'), 'Bermuda', 2020, Decimal('6.8900'), 0, None),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', Decimal('38137.50'), 'Bhutan', 2015, Decimal('2.0000'), 1, Decimal('2.45')),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', Decimal('38137.50'), 'Bhutan', 2016, Decimal('2.1600'), 1, None),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', Decimal('38137.50'), 'Bhutan', 2017, Decimal('2.4500'), 1, None)]

# %% [markdown]
# ### 2. Second `LEFT JOIN`
#
# Combine the previously joined tables with the `Basic_Services` table, again based on the `Country_name` column.

# %%
# %%sql
# # Add your code here
# # Use LIMIT if you expect a large result set
#
# SELECT
#     *
# FROM
#     Geographic_Location
# LEFT JOIN
#     Economic_Indicators ON Geographic_Location.Country_name = Economic_Indicators.Country_name
# LEFT JOIN
#     Basic_Services ON Geographic_Location.Country_name = Basic_Services.Country_name
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.0000'), 34, None, 'Afghanistan', 2015, Decimal('67.00'), Decimal('45.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.0000'), 34, None, 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.0000'), 34, None, 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.0000'), 34, None, 'Afghanistan', 2018, Decimal('75.33'), Decimal('50.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.0000'), 34, None, 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.0000'), 34, None, 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.0200'), 35, None, 'Afghanistan', 2015, Decimal('67.00'), Decimal('45.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.0200'), 35, None, 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.0200'), 35, None, 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.0200'), 35, None, 'Afghanistan', 2018, Decimal('75.33'), Decimal('50.67'))]

# %% [markdown]
# ### 3. Refine the second `LEFT JOIN`
#
# At first glance, the results of the above query might seem fine, but take a closer look at the `Time_periods`. We can see that they don't align as we would expect.
#
# Refine the second `LEFT JOIN` query by adding an additional condition based on the `Time_period` column.

# %%
# %%sql
# # Add your code here
# # Use LIMIT if you expect a large result set
#
# SELECT
#     *
# FROM
#     Geographic_Location
# LEFT JOIN
#     Economic_Indicators
#     ON Geographic_Location.Country_name = Economic_Indicators.Country_name
# LEFT JOIN
#     Basic_Services ON Geographic_Location.Country_name = Basic_Services.Country_name
#         AND Economic_Indicators.Time_period = Basic_Services.Time_period
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.0000'), 34, None, 'Afghanistan', 2015, Decimal('67.00'), Decimal('45.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.0200'), 35, None, 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.9000'), 36, Decimal('11.18'), 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.4200'), 37, None, 'Afghanistan', 2018, Decimal('75.33'), Decimal('50.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2019, Decimal('18.9000'), 38, None, 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2020, Decimal('20.1400'), 39, Decimal('11.71'), 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2015, Decimal('165.9800'), 40, Decimal('11.21'), 'Algeria', 2015, Decimal('92.00'), Decimal('85.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2016, Decimal('160.0300'), 40, Decimal('10.20'), 'Algeria', 2016, Decimal('93.00'), Decimal('85.33')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2017, Decimal('170.1000'), 41, Decimal('12.00'), 'Algeria', 2017, Decimal('93.00'), Decimal('84.67')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2018, Decimal('174.9100'), 42, None, 'Algeria', 2018, Decimal('93.00'), Decimal('84.67'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. First `LEFT JOIN`

# %%
# %%sql
#
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LEFT JOIN
# 	united_nations.Economic_Indicators as econ
# 	ON geo.Country_name = econ.Country_name
# LIMIT 50;

# %% [markdown]
# With this LEFT JOIN, we will get all the records from the `Geographic_Location` table and only the matching records from the `Economic_Indicators` table. If there is no match, we will still get the data from the `Geographic_Location` table, and the columns from the `Economic_Indicators` table will be `NULL`.

# %% [markdown]
# ### 2. Second `LEFT JOIN`

# %%
# %%sql
#
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LEFT JOIN
# 	united_nations.Economic_Indicators as econ
# 	ON geo.Country_name = econ.Country_name
# LEFT JOIN
# 	united_nations.Basic_Services as svc
# 	ON geo.Country_name = svc.Country_name
# LIMIT 20;

# %% [markdown]
# ### 3. Refine second `LEFT JOIN`

# %%
# %%sql
#
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LEFT JOIN
# 	united_nations.Economic_Indicators as econ
# 	ON geo.Country_name = econ.Country_name
# LEFT JOIN
# 	united_nations.Basic_Services as svc
# 	ON geo.Country_name = svc.Country_name
# 	AND econ.Time_period = svc.Time_period
# LIMIT 20;

# %% [markdown]
# With the additional condition, we ensure that the `Time_periods` align correctly and we get the desired output.

# %% [markdown]
# ## Summary
#
# This notebook shows how Entity-Relationship Diagrams can help us understand database joins better. We specifically focused on the `LEFT JOIN` technique, which is widely used to combine tables. Additionally, we noticed the importance of picking the right joining strategy, as incorrect joins can lead to inaccurate results.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
